# %% [markdown]
# ## Line Plot

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = [0, 1, 2, 3, 4, 5]
y = [0, 3, 2, 22, 22, 10]
plt.plot(x, y)
plt.xlim(1, 5)
plt.ylim(0, 15)
plt.xlabel("days")
plt.ylabel("counts")
plt.show()

# %% [markdown]
# ### Line plot Axis controls

# %%
import numpy as np
f = 50
x = np.arange(0, 400)
y = np.cos(2*np.pi*f*x/2000)
plt.plot(x, y)
plt.xlim(300, 400)
# plt.ylim(-0.5, 0.5)
plt.xlabel("time")
plt.ylabel("amplitude")
plt.show()

# %% [markdown]
# ### Multi-line line plots
#
#
# *   Labels and Legends

# %%
x = [0, 1, 2, 3, 4, 5]
y1 = [0, 3, 2, 22, 22, 10]
y2 = [1, 7, 5, 4, 3, 8]
plt.plot(x, y1, c="g", label="location1")
plt.plot(x, y2, c="r", label="location2")
plt.xlabel("days")
plt.ylabel("counts")
plt.legend()
plt.show()
# Colors: r:red, g:green, b:blue, m:magenta, c:cyan, k:black

# %% [markdown]
# ## Bar Charts

# %%
x = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday"]
item_1_sales = [1, 2, 3, 4, 5]
plt.bar(x, item_1_sales, label="item1")
plt.xlabel("Days")
plt.ylabel("Counts")
plt.savefig("bar_chart.png", dpi=300)
plt.show()

# %%
x = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday"]
item_1_sales = [1, 2, 3, 4, 5]
item_2_sales = [3, 4, 5, 6, 5]
plt.bar(x, item_1_sales, color="r", label="item1")
plt.bar(x, item_2_sales, color="b", alpha=0.2,label="item2")
plt.xlabel("Days")
plt.ylabel("Counts")
plt.legend()
plt.savefig("bar_chart.png", dpi=300)
plt.show()

# %% [markdown]
# ## Pie Charts

# %%
countries = ["India", "USA", "UK", "UAE"]
population = [123, 20, 30, 40]
plt.pie(population, labels=countries, autopct="%1.2f%%")
plt.show()

# %% [markdown]
# ## Histograms

# %%
import pandas as pd
data = pd.read_csv("auto-mpg.csv")

# %%
plt.hist(data["mpg"], color="green", rwidth=0.9)
plt.title("Histogram of MPG")
plt.xlabel("MPG")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ## Kernel Density Estimation (KDE) Plot

# %%
data["mpg"].plot.kde()
plt.show()

# %%
# !pip install folium

# %% [markdown]
# ## Maps Using Open Street Maps

# %%
import folium

latitude = 8.5559403
longitude = 76.876830
my_map = folium.Map(location=[latitude, longitude], zoom_start=50)
folium.Marker([latitude, longitude], popup="Technopark Trivandrum").add_to(my_map)

# Display the map
my_map.save("tvm.html")

# %%
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %% [markdown]
# ## Scatter Plot

# %%
import pandas as pd
data = pd.read_csv("auto-mpg.csv")
plt.figure(figsize=(6, 3.5))
plt.scatter(data["weight"], data["mpg"], marker="o")
plt.title("MPG vs Weight")
plt.xlabel("Weight")
plt.ylabel("MPG")
plt.show()

# %% [markdown]
# ## Sub-Figures

# %%
plt.figure(figsize=(5, 12))
plt.subplot(2, 1, 1)
plt.scatter(data["weight"], data["mpg"], c="k")
plt.ylabel("MPG")
plt.xlabel("Weight")
plt.subplot(2, 1, 2)
plt.hist(data["displacement"])
plt.xlabel("Displacement")
plt.ylabel("MPG")
plt.show()

# %%
x = np.random.normal(170, 10, 1000000)
plt.hist(x, bins=100)
plt.show()

# %%
y = np.random.uniform(0, 10, 250000)
plt.hist(y)
plt.show()

# %%
# a = np.random.normal(190, 5, 20000)
b = np.random.normal(200, 7, 20000)
# plt.hist(a, bins=200, color="green")
plt.hist(b, bins=200, color="red", alpha=0.6)
plt.show()

# %% [markdown]
# ## CDF plot

# %%
a = np.random.normal(160, 5, 20000)
plt.hist(a, bins=200, density=True, cumulative=True, color="green")
plt.show()

# %%
a = np.random.normal(170, 1, 20000)
b = np.random.normal(155, 5, 20000)
plt.scatter(a,b, c="green")

# %%
c = a*-10+b
plt.scatter(a,c, c="green")

# %% [markdown]
# ## Heatmaps

# %%
import numpy as np
import seaborn as sns
heat_data = np.array([[0, 0.4, 1], [1, 0.4, 0]])
sns.heatmap(heat_data)
plt.show()

# %% [markdown]
# ## Trainguar Correlation Heatmap

# %%
import seaborn as sns
import matplotlib.pyplot as plt

data = pd.read_csv("auto-mpg.csv")
data_new = data.drop(["car name", "horsepower"], axis=1)
corr_mat = data_new.corr()
mask = np.triu(np.ones_like(corr_mat, dtype=bool))
sns.heatmap(corr_mat, mask=mask, annot=True, cmap='viridis')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Box Plot

# %%
x = np.arange(1,1000)
q1 = np.percentile(x, 25)
q2 = np.percentile(x, 50)
q3 = np.percentile(x, 75)
iqr = q3-q1
lower_bound = q1-(1.5*iqr)
upper_bound = q3+(1.5*iqr)

# %%
data = pd.read_csv("auto-mpg.csv")
num_df = data.select_dtypes(include=np.number)
plt.boxplot(num_df)
plt.show()

# %%
sns.boxplot(num_df)
plt.xticks(rotation=45)
plt.show()

# %%
n_cylinders = data["cylinders"].value_counts()

# %%
n_cylinders.plot.bar()
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ## Annotating with equations

# %%
import numpy as np
f = 10
x = np.arange(0, 400)
y1 = np.cos(2*np.pi*f*x/2000)
y2 = np.sin(2*np.pi*f*x/2000)
plt.plot(x, y1, c="k", label='$y=cos(x)$')
plt.plot(x, y2, c="b", alpha=0.8, label='$y=sin(x)$')
plt.legend(loc='upper right')
plt.xlabel("time")
plt.ylabel("Amplitude")
plt.text(100, 1, "some waves")
plt.grid()
plt.show()

# %% [markdown]
# ## Images

# %%
x = np.arange(0, 400).reshape(20,20)
plt.imshow(x)
plt.yticks([])
plt.show()

# %% [markdown]
# ## Multiple Axis Graphs

# %%
fig1, ax1 = plt.subplots()
x = np.arange(0, 400)
y1 = 100*np.cos(2*np.pi*f*x/2000)
y2 = np.sin(2*np.pi*f*x/2000)
ax2 = ax1.twinx()
ax1.plot(x, y1, label='Signal 1', c='k', linestyle='--')
ax2.plot(x, y2, label='Signal 2', c='b')
ax1.legend()
ax2.legend()
plt.show()
